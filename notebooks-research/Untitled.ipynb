# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_parquet(r'C:\Users\sasir\Documents\Obfuscated-MalMem2022.parquet')

# %%
df
# Out:
#                                                 Category  pslist.nproc  \
# 0                                                 Benign            45
# 1                                                 Benign            47
# 2                                                 Benign            40
# 3                                                 Benign            32
# 4                                                 Benign            42
# ...                                                  ...           ...
# 58053  Ransomware-Shade-fa03be3078d1b9840f06745f160eb...            37
# 58054  Ransomware-Shade-f56687137caf9a67678cde91e4614...            37
# 58055  Ransomware-Shade-faddeea111a25da4d0888f3044ae9...            38
# 58056  Ransomware-Shade-f866c086af2e1d8ebaa6f2c863157...            37
# 58057  Ransomware-Shade-955d9af38346c1755527bd196668e...            38
#
#        pslist.nppid  pslist.avg_threads  pslist.nprocs64bit  \
# ...

# %%
df["Category_clean"] = (
    df["Category"]
    .str.split("-", n=2)
    .str[:2]
    .str.join("-")
)

# %%
unique_categories = df["Category_clean"].drop_duplicates()
unique_categories
# Out:
# 0                      Benign
# 29227          Ransomware-Ako
# 29537        Ransomware-Conti
# 31525         Ransomware-Maze
# 33279         Ransomware-Pysa
# 34618        Ransomware-Shade
# 35056    Spyware-180solutions
# 37056             Spyware-CWS
# 39056           Spyware-Gator
# 41051            Spyware-TIBS
# 42461     Spyware-Transponder
# 44871           Trojan-Emotet
# 46838          Trojan-Reconyc
# 48408          Trojan-Refroso
# 50408             Trojan-Scar
# 52408             Trojan-Zeus
# Name: Category_clean, dtype: object

# %%
# Option 1: Using your new 'Category_clean' column (Recommended)
gator_df = df[df["Category_clean"] == "Spyware-Gator"]

# Option 2: Using the original 'Category' column with a text search
# gator_df = df[df["Category"].str.contains("Spyware-Gator")]

# %%
gator_df
# Out:
#                                                 Category  pslist.nproc  \
# 39056  Spyware-Gator-00a316e53de939f82885157ce057f134...            45
# 39057  Spyware-Gator-00a316e53de939f82885157ce057f134...            42
# 39058  Spyware-Gator-00a316e53de939f82885157ce057f134...            44
# 39059  Spyware-Gator-00a316e53de939f82885157ce057f134...            46
# 39060  Spyware-Gator-00a316e53de939f82885157ce057f134...            46
# ...                                                  ...           ...
# 41046  Spyware-Gator-ffe76c4c92ee691e8b4a4044f0db7ca1...            44
# 41047  Spyware-Gator-ffe76c4c92ee691e8b4a4044f0db7ca1...            43
# 41048  Spyware-Gator-ffe76c4c92ee691e8b4a4044f0db7ca1...            43
# 41049  Spyware-Gator-ffe76c4c92ee691e8b4a4044f0db7ca1...            43
# 41050  Spyware-Gator-ffe76c4c92ee691e8b4a4044f0db7ca1...            42
#
#        pslist.nppid  pslist.avg_threads  pslist.nprocs64bit  \
# ...

# %%
# Check how many samples you found
print(f"Found {len(gator_df)} Gator samples.")
# Out:
# Found 1995 Gator samples.

# %%
# Save to a new CSV file for testing
gator_df.to_csv("test_spyware_gator.csv", index=False)

# %%
df.to_csv("test.csv", index=False)

# %%
gator_df.columns
# Out:
# Index(['Category', 'pslist.nproc', 'pslist.nppid', 'pslist.avg_threads',
#        'pslist.nprocs64bit', 'pslist.avg_handlers', 'dlllist.ndlls',
#        'dlllist.avg_dlls_per_proc', 'handles.nhandles',
#        'handles.avg_handles_per_proc', 'handles.nport', 'handles.nfile',
#        'handles.nevent', 'handles.ndesktop', 'handles.nkey', 'handles.nthread',
#        'handles.ndirectory', 'handles.nsemaphore', 'handles.ntimer',
#        'handles.nsection', 'handles.nmutant', 'ldrmodules.not_in_load',
#        'ldrmodules.not_in_init', 'ldrmodules.not_in_mem',
#        'ldrmodules.not_in_load_avg', 'ldrmodules.not_in_init_avg',
#        'ldrmodules.not_in_mem_avg', 'malfind.ninjections',
#        'malfind.commitCharge', 'malfind.protection',
#        'malfind.uniqueInjections', 'psxview.not_in_pslist',
#        'psxview.not_in_eprocess_pool', 'psxview.not_in_ethread_pool',
#        'psxview.not_in_pspcid_list', 'psxview.not_in_csrss_handles',
# ...
